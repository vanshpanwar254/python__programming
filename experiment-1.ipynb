# %% [markdown]
# #Python Programming Lab
# ##Experiment 1: Python Installation and starting with python
#
# ###1. Install Python and understand difference between scripting and interactive modes in IDLE.

# %%
#Scripting Mode: Write Python code in a .py file, then run the full program at once.
name = "Vansh Panwar"
print("Hello", name)
# Out:
# Hello Vansh Panwar

# %%
#Interactive Mode: Have to type Python commands one by one, and Python gives the output immediately.
5 + 2
7
name = "Vansh Panwar"
name
'vansh'
# Out:
# 'vansh'

# %% [markdown]
# ###Write Python programs to print strings in the given manner:
# a) Hello Everyone !!!
# b) Hello
# World
# c) Hello
# World
# d) ‘ Rohit’ s date of birth is 12\05\1999’

# %%
print("Hello Everyone")
# Out:
# Hello Everyone

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Hello \n   World")
# Out:
# Hello
#    World

# %%
print("Vansh Panwar date of birth is 12\\05\\1999")
# Out:
# Vansh Panwar date of birth is 12\05\1999

# %% [markdown]
# ###3.Declare a string variable called x and assign it the value “Hello”.
# Print out the value of x

# %%
x = "Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# ###4.Take different data types and print values using print function.

# %%
name = "Vansh Panwar"      
age = 20             
height = 6.01           
is_student = True      
marks = [82, 87, 80]   

print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Is Student:", is_student)
print("Marks:", marks)
# Out:
# Name: Vansh Panwar
# Age: 20
# Height: 6.01
# Is Student: True
# Marks: [82, 87, 80]
